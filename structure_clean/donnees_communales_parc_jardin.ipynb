# %%
import pandas as pd
import numpy as np
import re

from pathlib import Path

path = "../data/donnees_communales_parc_jardin.csv"

def compose_address(row):
    parts = []
    for c in ["num", "numvoie", "voie"]:
        if c in row.index and pd.notna(row[c]) and str(row[c]).strip():
            parts.append(str(row[c]).strip())
    return " ".join(parts).strip() or np.nan

# %% [markdown]
# # Infos

# %%
df = pd.read_csv(path)
display(df.head(3)) 
df.info()
# Out:
#                                               FID              uid id_ariane  \
# 0  com_donnees_communales.comparcjardin_1_0_0.371    PAR-69204-001       NaN
# 1  com_donnees_communales.comparcjardin_1_0_0.372    PAR-69204-002       NaN
# 2   com_donnees_communales.comparcjardin_1_0_0.76  PAR-69385-05110     S8220
#
#                              nom   num numvoie                       voie  \
# 0  Parc historique de Beauregard     1     NaN        Rue Edouard Millaud
# 1   Parc de la Maison des Champs     2     130  Avenue Georges Clemenceau
# 2           Jardin André Malraux  5110     NaN          Place des Minimes
#
#    codepost                 commune  code_insee  ...  eau  toilettes  \
# 0   69230.0       Saint-Genis-Laval     69204.0  ...  oui        oui
# 1   69230.0       Saint-Genis-Laval     69204.0  ...  non        non
# 2   69005.0  Lyon 5e Arrondissement     69385.0  ...  oui        non
#
#              chien   esp_can photo  gid  \
# 0  Tenus en laisse       Non   NaN  371
# 1  Tenus en laisse  Propreté   NaN  372
# 2              Oui       Non     0   76
#
#                                             the_geom           openinghours  \
# 0  MULTIPOLYGON (((4.786552 45.69293704090367, 4....  ["Mo-Su 08:00-18:00"]
# 1  MULTIPOLYGON (((4.792575 45.69654604090331, 4....  ["Mo-Su 08:00-18:00"]
# 2  MULTIPOLYGON (((4.821792696554102 45.758162063...                     []
#
#            last_update_fme horaires
# 0   2022-03-31T14:13:25.31      NaN
# 1   2022-03-31T14:13:25.63      NaN
# 2  2025-07-25T08:55:31.762      NaN
#
# [3 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 627 entries, 0 to 626
# Data columns (total 31 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   FID                        627 non-null    object
#  1   uid                        627 non-null    object
#  2   id_ariane                  318 non-null    object
#  3   nom                        627 non-null    object
#  4   num                        627 non-null    int64
#  5   numvoie                    324 non-null    object
#  6   voie                       623 non-null    object
#  7   codepost                   625 non-null    float64
#  8   commune                    625 non-null    object
#  9   code_insee                 625 non-null    float64
#  10  reglement                  568 non-null    object
#  11  surf_tot_m2                577 non-null    float64
#  12  gestion                    621 non-null    object
#  13  ann_ouvert                 120 non-null    float64
#  14  clos                       573 non-null    object
#  15  openinghoursspecification  64 non-null     object
#  16  precision_horaires         2 non-null      object
#  17  acces                      441 non-null    object
#  18  circulation                282 non-null    object
#  19  label                      515 non-null    object
#  20  type_equip                 414 non-null    object
#  21  eau                        566 non-null    object
#  22  toilettes                  576 non-null    object
#  23  chien                      556 non-null    object
#  24  esp_can                    493 non-null    object
#  25  photo                      370 non-null    object
#  26  gid                        627 non-null    int64
#  27  the_geom                   627 non-null    object
#  28  openinghours               564 non-null    object
#  29  last_update_fme            608 non-null    object
#  30  horaires                   160 non-null    object
# dtypes: float64(4), int64(2), object(25)
# memory usage: 152.0+ KB

# %% [markdown]
# # Standardisation des noms et nettoyage de base

# %%
parcs = pd.DataFrame()
parcs["adresse"] = df.apply(compose_address, axis=1)
parcs["commune"] = df["commune"].astype(str).str.strip()
parcs["surface_m2"] = (
    df["surf_tot_m2"]
    .astype(str)
    .str.replace(",", ".", regex=False)
    .str.extract(r"([\d\.]+)", expand=False)
    .astype(float)
)

if "type_equip" in df.columns:
    parcs["aire_jeu"] = df["type_equip"].str.contains("Aire de jeux", case=False, na=False)
else:
    parcs["aire_jeu"] = False

if "eau" in df.columns:
    parcs["eau"] = df["eau"].astype(str).str.lower().eq("oui")
else:
    parcs["eau"] = False

if "toilettes" in df.columns:
    parcs["toilettes"] = df["toilettes"].astype(str).str.lower().eq("oui")
else:
    parcs["toilettes"] = False

# %% [markdown]
# # Suppression des colonnes inutiles

# %%
colonnes_a_supprimer = [
    "FID","uid","id_ariane","codepost","esp_can","photo","openinghours",
    "last_update_fme","horaires","reglement","gestion","ann_ouvert",
    "precision_horaires","circulation","acces","label","clos",
    "openinghoursspecification","gid"
]
df = df.drop(columns=[c for c in colonnes_a_supprimer if c in df.columns], errors="ignore")

# %% [markdown]
# # Nettoyage du contenu

# %%
if "code_insee" in df.columns:
    df["code_insee"] = df["code_insee"].astype(str).str.replace(r"\.0$", "", regex=True).str.strip()
    parcs["code_insee"] = df["code_insee"]

if "the_geom" in df.columns:
    def extraire_coords(geom):
        if pd.isna(geom): return np.nan, np.nan
        geom_str = re.sub(r"[A-Z\(\)]", " ", str(geom))
        match = re.search(r"([-+]?\d+\.\d+)\s+([-+]?\d+\.\d+)", geom_str)
        return (float(match.group(1)), float(match.group(2))) if match else (np.nan, np.nan)
    coords = df["the_geom"].apply(lambda g: pd.Series(extraire_coords(g)))
    coords.columns = ["longitude", "latitude"]
    parcs = pd.concat([parcs.reset_index(drop=True), coords.reset_index(drop=True)], axis=1)

def normalize_text(s):
    if pd.isna(s): return s
    return re.sub(r"\s+", " ", str(s).strip())

for col in ["adresse","commune","eau","toilettes","aire_jeu"]:
    if col in parcs.columns:
        parcs[col] = parcs[col].map(normalize_text)

parcs = parcs.dropna(subset=["adresse"])
parcs["adresse"] = parcs["adresse"].str.replace(r"\s+"," ",regex=True).str.strip()
subset_dups = [c for c in ["adresse","commune"] if c in parcs.columns]
parcs = parcs.drop_duplicates(subset=subset_dups)

# %%
parcs.head(10)
# Out:
#                                 adresse                 commune    surface_m2  \
# 0                 1 Rue Edouard Millaud       Saint-Genis-Laval  36358.950000
# 1       2 130 Avenue Georges Clemenceau       Saint-Genis-Laval   4506.040000
# 2                5110 Place des Minimes  Lyon 5e Arrondissement   3334.820000
# 3                    6073 Rue Tête d'Or  Lyon 6e Arrondissement   2094.410000
# 4              8138 7 Rue du Presbytere  Lyon 8e Arrondissement   1330.870000
# 5                7105 390 Rue Garibaldi  Lyon 7e Arrondissement   2037.580000
# 6                6049 147 Rue de Créqui  Lyon 6e Arrondissement   2642.520000
# 7  8 10 Boulevard De Lattre de Tassigny        Rillieux-la-Pape  10804.000000
# 8                    56130 2 Rue Barème  Lyon 6e Arrondissement           NaN
# 9                      40 33 Rue Armand            Villeurbanne   3423.625396
#
#   aire_jeu    eau toilettes code_insee  longitude   latitude
# 0    False   True      True      69204   4.786552  45.692937
# 1    False  False     False      69204   4.792575  45.696546
# 2    False   True     False      69385   4.821793  45.758162
# 3     True   True     False      69386   4.852025  45.766371
# 4     True  False     False      69388   4.851964  45.735282
# 5     True  False     False      69387   4.846837  45.744334
# 6    False  False     False      69386   4.847663  45.764203
# 7     True   True      True      69286   4.904408  45.812028
# 8    False  False     False      69386   4.842589  45.774183
# 9     True   True     False      69266   4.886612  45.779803

# %% [markdown]
# # export des donner

# %%
parcs.to_csv("../csv_clean/parcs_jardins_communes_clean.csv", index=False)
print("✅ Fichier écrit : parcs_jardins_communes_agg.csv")
# Out:
# ✅ Fichier écrit : parcs_jardins_communes_agg.csv
